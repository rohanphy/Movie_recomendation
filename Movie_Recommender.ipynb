# %% [markdown]
# **Importing Important Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
from textblob import TextBlob
from wordcloud import WordCloud,STOPWORDS

import warnings
warnings.filterwarnings('ignore')

# %%
#Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Data Set**

# %%
keywords = pd.read_csv('/content/drive/MyDrive/csv_data/keywords.csv')
metadata = pd.read_csv('/content/drive/MyDrive/csv_data/movies_metadata.csv')
credits = pd.read_csv('/content/drive/MyDrive/csv_data/credits.csv')
ratings = pd.read_csv('/content/drive/MyDrive/csv_data/ratings.csv')

# %%
data_names = ['credits', 'keywords', 'metadata', 'ratings']
count = 0

# for each imported dataset display head of the data
for data in [credits, keywords, metadata, ratings]:
    print('\n\n\n\033[33mHead of the', data_names[count] , 'data\033[0m')
    display(data.head())
    print(data.shape)
    count += 1
# Out:
# Head of the credits data
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
# (45476, 3)
#
#
#
# Head of the keywords data
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# (46419, 2)
#
#
#
# Head of the metadata data
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]
# (45466, 24)
#
#
#
# Head of the ratings data
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556
# (26024289, 4)

# %%
print(metadata.id.dtypes) # id types needs to be converted into integer
# Out:
# object

# %%
metadata2 = metadata
# Some of the data points in id column have dates insted of id so replace those id with NaN
metadata2['id'] = metadata2['id'].apply(lambda x: x if len(x.split('-'))==1 else np.nan)

# %%
metadata2.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           3
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
metadata3 = metadata2.dropna(subset=['id'])
metadata3 = metadata3.drop('imdb_id', axis=1)

# %%
ratings_column_renamed = ratings.rename(index=str, columns={'movieId':'id'})
metadata3['id'] = metadata3['id'].astype(int)
#merged = ratings_column_renamed.merge(metadata3, on='id')
data = metadata3.merge(keywords, on='id')
data = data.merge(credits, on='id')

# %% [markdown]
# # **Data Pre Processing**

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.isnull())
plt.title("Missing values?", fontsize = 15, color='red')
plt.show()

# %% [markdown]
# **Observation:**
# 1. Homepage and Tagline columns seems to have very large null values hence we will drop them.
# 2. Belongs to collection also have large number of null values but those movies might not belong to any collection hence we will keep it.

# %%
len(data[(data['status']!='Released')]) # Movies which has not been released so far
# Out:
# 464

# %%
data2 = data[(data['status']=='Released')]
data2 = data2.dropna(subset=['popularity'])

# %%
data3 = data2.fillna('Not Available') # All the null values will be filled with not available

# %%
data4 = data3.drop(['homepage', 'poster_path', 'tagline', 'title', 'video'], axis=1)

# %%
count = 0
for title in list(data4.original_title.unique()):
    same_title_movies = data4[(data4['original_title']==title)]
    if len(same_title_movies) > 1:
        print('\033[91m' + 'Movies having the name ' + title + '\033[0m')
        display(same_title_movies)
        print('\n\n')
        count = count + 1
    if count > 10: break
# Out:
# Movies having the name Heat
#        adult belongs_to_collection    budget  \
# 5      False         Not Available  60000000
# 14856  False         Not Available         0
# 29255  False         Not Available         0
#
#                                                   genres     id  \
# 5      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    949
# 14856  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   4579
# 29255  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...  42023
#
#       original_language original_title  \
# 5                    en           Heat
# 14856                en           Heat
# 29255                en           Heat
#
#                                                 overview popularity  \
# 5      Obsessive master thief, Neil McCauley leads a ...  17.924927
# 14856  Former child star Joe Davis (Joe Dallesandro),...   0.466019
# 29255  Reynolds plays an ex-soldier-of-fortunish char...   1.352232
#
#                                     production_companies  ... release_date  \
# 5      [{'name': 'Regency Enterprises', 'id': 508}, {...  ...   1995-12-15
# 14856  [{'name': 'Andy Warhol Productions', 'id': 100...  ...   1972-10-06
# 29255  [{'name': 'New Century Productions', 'id': 866...  ...   1986-01-01
#
#            revenue  runtime  \
# 5      187436818.0    170.0
# 14856          0.0    102.0
# 29255          0.0    101.0
#
#                                         spoken_languages    status  \
# 5      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 14856           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29255           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#       vote_average  vote_count  \
# 5              7.7      1886.0
# 14856          6.3         6.0
# 29255          5.2         5.0
#
#                                                 keywords  \
# 5      [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 14856  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 29255                                                 []
#
#                                                     cast  \
# 5      [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 14856  [{'cast_id': 4, 'character': 'Joey', 'credit_i...
# 29255  [{'cast_id': 4, 'character': 'Mex', 'credit_id...
#
#                                                     crew
# 5      [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 14856  [{'credit_id': '52fe43cec3a36847f8070f75', 'de...
# 29255  [{'credit_id': '52fe45e9c3a36847f80e1adf', 'de...
#
# [3 rows x 21 columns]
# Movies having the name Sabrina
#      adult belongs_to_collection    budget  \
# 6    False         Not Available  58000000
# 902  False         Not Available   2238813
#
#                                                 genres     id  \
# 6    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  11860
# 902  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   6620
#
#     original_language original_title  \
# 6                  en        Sabrina
# 902                en        Sabrina
#
#                                               overview popularity  \
# 6    An ugly duckling having undergone a remarkable...   6.677277
# 902  Linus and David Larrabee are the two sons of a...   7.359741
#
#                                   production_companies  ... release_date  \
# 6    [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...   1995-12-15
# 902          [{'name': 'Paramount Pictures', 'id': 4}]  ...   1954-09-28
#
#         revenue  runtime                                   spoken_languages  \
# 6           0.0    127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 902  10000000.0    113.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#        status vote_average  vote_count  \
# 6    Released          6.2       141.0
# 902  Released          7.4       284.0
#
#                                               keywords  \
# 6    [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# 902  [{'id': 380, 'name': 'brother brother relation...
#
#                                                   cast  \
# 6    [{'cast_id': 1, 'character': 'Linus Larrabee',...
# 902  [{'cast_id': 5, 'character': 'Linus Larrabee',...
#
#                                                   crew
# 6    [{'credit_id': '52fe44959251416c75039da9', 'de...
# 902  [{'credit_id': '52fe445fc3a36847f8091fb3', 'de...
#
# [2 rows x 21 columns]
# Movies having the name Sense and Sensibility
#        adult belongs_to_collection    budget  \
# 16     False         Not Available  16500000
# 28580  False         Not Available         0
# 41989  False         Not Available         0
# 42208  False         Not Available         0
#
#                                                   genres      id  \
# 16     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...    4584
# 28580                      [{'id': 18, 'name': 'Drama'}]  315010
# 41989  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  391934
# 42208                                                 []  243987
#
#       original_language         original_title  \
# 16                   en  Sense and Sensibility
# 28580                en  Sense and Sensibility
# 41989                en  Sense and Sensibility
# 42208                en  Sense and Sensibility
#
#                                                 overview popularity  \
# 16     Rich Mr. Dashwood dies, leaving his second wif...  10.673167
# 28580  This is the acclaimed 2008 BBC adaptation of t...   1.724436
# 41989  Two sisters of opposing temperaments find love...   0.416171
# 42208               Adaptation of the Jane Austen novel.   0.010759
#
#                                     production_companies  ... release_date  \
# 16     [{'name': 'Columbia Pictures Corporation', 'id...  ...   1995-12-13
# 28580  [{'name': 'BBC Worldwide', 'id': 3164}, {'name...  ...   2008-01-01
# 41989  [{'name': 'British Broadcasting Corporation (B...  ...   1981-02-01
# 42208                                                 []  ...   1971-01-01
#
#            revenue  runtime                          spoken_languages  \
# 16     135000000.0    136.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 28580          0.0    174.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 41989          0.0    174.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 42208          0.0    178.0                                        []
#
#          status vote_average  vote_count  \
# 16     Released          7.2       364.0
# 28580  Released          7.9        19.0
# 41989  Released          0.0         0.0
# 42208  Released          0.0         0.0
#
#                                                 keywords  \
# 16     [{'id': 420, 'name': 'bowling'}, {'id': 818, '...
# 28580                                                 []
# 41989  [{'id': 392, 'name': 'england'}, {'id': 7564, ...
# 42208                                                 []
#
#                                                     cast  \
# 16     [{'cast_id': 6, 'character': 'Marianne Dashwoo...
# 28580  [{'cast_id': 1, 'character': 'Elinor Dashwood'...
# 41989  [{'cast_id': 0, 'character': 'Elinor Dashwood'...
# 42208  [{'cast_id': 1, 'character': 'Elinor', 'credit...
#
#                                                     crew
# 16     [{'credit_id': '52fe43cec3a36847f807101f', 'de...
# 28580  [{'credit_id': '54a48c469251411860005dac', 'de...
# 41989  [{'credit_id': '5707bbcb9251412b0e002ac9', 'de...
# 42208  [{'credit_id': '52fe4ee8c3a36847f82afeff', 'de...
#
# [4 rows x 21 columns]
# Movies having the name Othello
#        adult belongs_to_collection budget  \
# 25     False         Not Available      0
# 2760   False         Not Available      0
# 15518  False         Not Available      0
# 21473  False         Not Available      0
#
#                                                   genres      id  \
# 25                         [{'id': 18, 'name': 'Drama'}]   16420
# 2760   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   47697
# 15518                      [{'id': 18, 'name': 'Drama'}]   44006
# 21473                                                 []  119928
#
#       original_language original_title  \
# 25                   en        Othello
# 2760                 en        Othello
# 15518                en        Othello
# 21473                en        Othello
#
#                                                 overview popularity  \
# 25     The evil Iago pretends to be friend of Othello...   1.845899
# 2760   Desdemona, daughter of a Venetian aristocrat, ...   2.698585
# 15518          The 1965 version of the Shakespeare play.   0.377325
# 21473  Iago and a comrade-in-arms are outside the Ven...   0.653579
#
#                                     production_companies  ... release_date  \
# 25     [{'name': 'Columbia Pictures', 'id': 5}, {'nam...  ...   1995-12-15
# 2760   [{'name': 'Les Films Marceau', 'id': 2260}, {'...  ...   1951-11-27
# 15518  [{'name': 'BHE Films', 'id': 2008}, {'name': '...  ...   1965-12-15
# 21473                                                 []  ...   1981-10-04
#
#       revenue  runtime                          spoken_languages    status  \
# 25        0.0    123.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2760      0.0     90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15518     0.0    165.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 21473     0.0    204.0                                        []  Released
#
#       vote_average  vote_count  \
# 25             7.0        33.0
# 2760           6.5        35.0
# 15518          6.1         9.0
# 21473          9.5         2.0
#
#                                                 keywords  \
# 25     [{'id': 497, 'name': 'shakespeare'}, {'id': 93...
# 2760   [{'id': 497, 'name': 'shakespeare'}, {'id': 11...
# 15518  [{'id': 497, 'name': 'shakespeare'}, {'id': 96...
# 21473                                                 []
#
#                                                     cast  \
# 25     [{'cast_id': 2, 'character': 'Othello', 'credi...
# 2760   [{'cast_id': 5, 'character': 'Othello', 'credi...
# 15518  [{'cast_id': 2, 'character': 'Othello', 'credi...
# 21473  [{'cast_id': 1, 'character': '', 'credit_id': ...
#
#                                                     crew
# 25     [{'credit_id': '5462510ec3a368082d000121', 'de...
# 2760   [{'credit_id': '52fe4740c3a36847f812b8d3', 'de...
# 15518  [{'credit_id': '52fe4671c3a36847f80ff483', 'de...
# 21473  [{'credit_id': '52fe4c10c3a36847f821fd17', 'de...
#
# [4 rows x 21 columns]
# Movies having the name Persuasion
#        adult belongs_to_collection budget  \
# 27     False         Not Available      0
# 15010  False         Not Available      0
# 42003  False         Not Available      0
#
#                                                   genres      id  \
# 27     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   17015
# 15010  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   13949
# 42003                                                 []  243984
#
#       original_language original_title  \
# 27                   en     Persuasion
# 15010                en     Persuasion
# 42003                en     Persuasion
#
#                                                 overview popularity  \
# 27     This film adaptation of Jane Austen's last nov...   2.228434
# 15010  Persuasion is the newest adaptation of the cla...   6.955841
# 42003               Adaptation of the Jane Austen novel.   0.001459
#
#                                     production_companies  ... release_date  \
# 27                    [{'name': 'BBC Films', 'id': 288}]  ...   1995-09-27
# 15010  [{'name': 'WGBH', 'id': 3449}, {'name': 'Clerk...  ...   2007-04-01
# 42003                                                 []  ...   1971-01-01
#
#       revenue  runtime                          spoken_languages    status  \
# 27        0.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15010     0.0     93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 42003     0.0    300.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#       vote_average  vote_count  \
# 27             7.4        36.0
# 15010          7.1        52.0
# 42003          0.0         0.0
#
#                                                 keywords  \
# 27     [{'id': 1316, 'name': 'captain'}, {'id': 33384...
# 15010  [{'id': 128, 'name': 'love triangle'}, {'id': ...
# 42003                                                 []
#
#                                                     cast  \
# 27     [{'cast_id': 1, 'character': 'Anne Elliott', '...
# 15010  [{'cast_id': 1, 'character': 'Anne Elliot', 'c...
# 42003  [{'cast_id': 1, 'character': 'Anne Elliot', 'c...
#
#                                                     crew
# 27     [{'credit_id': '52fe46ff9251416c7508a8b3', 'de...
# 15010  [{'credit_id': '53569438c3a3687f1e00007e', 'de...
# 42003  [{'credit_id': '598dd6b6c3a3687559015d56', 'de...
#
# [3 rows x 21 columns]
# Movies having the name It Takes Two
#        adult belongs_to_collection budget  \
# 37     False         Not Available      0
# 29342  False         Not Available      0
#
#                                                   genres      id  \
# 37     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...   33689
# 29342  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  110538
#
#       original_language original_title  \
# 37                   en   It Takes Two
# 29342                en   It Takes Two
#
#                                                 overview popularity  \
# 37     Identical 9-year-olds from very different back...   7.777735
# 29342  Travis is due to marry Stephanie in a few days...    0.00243
#
#                                     production_companies  ... release_date  \
# 37     [{'name': 'Dualstar Productions', 'id': 6130},...  ...   1995-11-17
# 29342             [{'name': 'United Artists', 'id': 60}]  ...   1988-07-13
#
#       revenue  runtime                          spoken_languages    status  \
# 37        0.0    101.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29342     0.0     78.0                                        []  Released
#
#       vote_average  vote_count  \
# 37             6.1       149.0
# 29342          5.4         5.0
#
#                                                 keywords  \
# 37     [{'id': 13014, 'name': 'orphan'}, {'id': 20435...
# 29342                                                 []
#
#                                                     cast  \
# 37     [{'cast_id': 1, 'character': 'Diane Barrows', ...
# 29342  [{'cast_id': 2, 'character': 'Travis Rogers', ...
#
#                                                     crew
# 37     [{'credit_id': '52fe45309251416c9102a49d', 'de...
# 29342  [{'credit_id': '52fe4adbc3a36847f81e551d', 'de...
#
# [2 rows x 21 columns]
# Movies having the name Cry, the Beloved Country
#        adult belongs_to_collection budget                         genres  \
# 39     False         Not Available      0  [{'id': 18, 'name': 'Drama'}]
# 26881  False         Not Available      0  [{'id': 18, 'name': 'Drama'}]
#
#            id original_language            original_title  \
# 39      34615                en  Cry, the Beloved Country
# 26881  173893                en  Cry, the Beloved Country
#
#                                                 overview popularity  \
# 39     A South-African preacher goes to search for hi...   0.894647
# 26881  In the back country of South Africa, black min...   0.691117
#
#                                     production_companies  ... release_date  \
# 39     [{'name': 'Miramax', 'id': 53009}, {'name': 'D...  ...   1995-12-15
# 26881   [{'name': 'London Film Productions', 'id': 659}]  ...   1952-04-26
#
#         revenue  runtime                          spoken_languages    status  \
# 39     676525.0    106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 26881       0.0    103.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#       vote_average  vote_count                                keywords  \
# 39             6.7        13.0  [{'id': 3644, 'name': 'south africa'}]
# 26881          6.7         3.0                                      []
#
#                                                     cast  \
# 39     [{'cast_id': 4, 'character': 'Rev. Stephen Kum...
# 26881  [{'cast_id': 1, 'character': 'Stephen Kumalo',...
#
#                                                     crew
# 39     [{'credit_id': '52fe456f9251416c91032375', 'de...
# 26881  [{'credit_id': '52fe4d3ec3a36847f82566f3', 'de...
#
# [2 rows x 21 columns]
# Movies having the name Richard III
#        adult belongs_to_collection budget  \
# 40     False         Not Available      0
# 7254   False         Not Available      0
# 17909  False         Not Available      0
#
#                                                   genres     id  \
# 40     [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...  31174
# 7254   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...  43323
# 17909                      [{'id': 18, 'name': 'Drama'}]  46758
#
#       original_language original_title  \
# 40                   en    Richard III
# 7254                 en    Richard III
# 17909                en    Richard III
#
#                                                 overview popularity  \
# 40     Shakespeare's Play transplanted into a 1930s s...   4.561387
# 7254   Shakespeare's powerful tale of the wicked defo...   1.971284
# 17909  Shakespeare's tragedy of the hump-backed Duke ...    0.05131
#
#                                     production_companies  ... release_date  \
# 40     [{'name': 'British Screen', 'id': 871}, {'name...  ...   1995-12-29
# 7254   [{'name': 'London Film Productions', 'id': 659...  ...   1955-12-13
# 17909  [{'name': "Le Film d'Art", 'id': 1573}, {'name...  ...   1912-10-15
#
#       revenue  runtime                                   spoken_languages  \
# 40        0.0    104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7254      0.0    161.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 17909     0.0     55.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status vote_average  vote_count  \
# 40     Released          6.9        50.0
# 7254   Released          6.8        26.0
# 17909  Released          0.0         1.0
#
#                                                 keywords  \
# 40     [{'id': 392, 'name': 'england'}, {'id': 497, '...
# 7254                [{'id': 497, 'name': 'shakespeare'}]
# 17909                                                 []
#
#                                                     cast  \
# 40     [{'cast_id': 1, 'character': 'Richard III', 'c...
# 7254   [{'cast_id': 3, 'character': 'King Edward IV o...
# 17909  [{'cast_id': 10, 'character': 'King Edward IV'...
#
#                                                     crew
# 40     [{'credit_id': '52fe44669251416c9100f5a3', 'de...
# 7254   [{'credit_id': '52fe463dc3a36847f80f413d', 'de...
# 17909  [{'credit_id': '570e9e78c3a368538b000432', 'de...
#
# [3 rows x 21 columns]
# Movies having the name Restoration
#        adult belongs_to_collection    budget  \
# 42     False         Not Available  19000000
# 39740  False         Not Available         0
#
#                                                   genres      id  \
# 42     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   35196
# 39740                     [{'id': 27, 'name': 'Horror'}]  396152
#
#       original_language original_title  \
# 42                   en    Restoration
# 39740                en    Restoration
#
#                                                 overview popularity  \
# 42     An aspiring young physician, Robert Merivel fo...  10.979269
# 39740  During home renovations, a young couple releas...   1.074124
#
#                         production_companies  ... release_date revenue  \
# 42     [{'name': 'Miramax Films', 'id': 14}]  ...   1995-12-29     0.0
# 39740                                     []  ...   2016-05-03     0.0
#
#        runtime                                   spoken_languages    status  \
# 42       117.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 39740     90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#       vote_average  vote_count  \
# 42             6.3        30.0
# 39740          5.3        11.0
#
#                                                 keywords  \
# 42     [{'id': 931, 'name': 'jealousy'}, {'id': 1279,...
# 39740                                                 []
#
#                                                     cast  \
# 42     [{'cast_id': 1, 'character': 'Robert Merivel',...
# 39740  [{'cast_id': 3, 'character': 'Rebecca Jordan',...
#
#                                                     crew
# 42     [{'credit_id': '52fe45999251416c91037fdf', 'de...
# 39740  [{'credit_id': '572bd470c3a368013d0002b1', 'de...
#
# [2 rows x 21 columns]
# Movies having the name Lamerica
#        adult belongs_to_collection budget  \
# 52     False         Not Available      0
# 39373  False         Not Available      0
#
#                                                   genres      id  \
# 52     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...   49133
# 39373                                                 []  384237
#
#       original_language original_title  \
# 52                   it       Lamerica
# 39373                en       Lamerica
#
#                                                 overview popularity  \
# 52     Fiore, an Italian conman, arrives in post Comm...   1.361286
# 39373  Lamerica is a cinematic documentary that takes...   0.040155
#
#       production_companies  ... release_date revenue  runtime  \
# 52                      []  ...   1994-01-01     0.0    116.0
# 39373                   []  ...   2015-10-15     0.0     43.0
#
#                                         spoken_languages    status  \
# 52     [{'iso_639_1': 'sq', 'name': 'shqip'}, {'iso_6...  Released
# 39373                                                 []  Released
#
#       vote_average  vote_count                                     keywords  \
# 52             7.7        11.0  [{'id': 10183, 'name': 'independent film'}]
# 39373          0.0         0.0                                           []
#
#                                                     cast  \
# 52     [{'cast_id': 2, 'character': 'Gino', 'credit_i...
# 39373                                                 []
#
#                                                     crew
# 52     [{'credit_id': '52fe4787c3a36847f813acf7', 'de...
# 39373  [{'credit_id': '56cc258e9251412452001fe5', 'de...
#
# [2 rows x 21 columns]
# Movies having the name Home for the Holidays
#        adult belongs_to_collection budget  \
# 56     False         Not Available      0
# 33785  False         Not Available      0
#
#                                                   genres     id  \
# 56     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   9089
# 33785  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...  30933
#
#       original_language         original_title  \
# 56                   en  Home for the Holidays
# 33785                en  Home for the Holidays
#
#                                                 overview popularity  \
# 56     After losing her job, making out with her soon...   8.416802
# 33785  An ailing man summons his four daughters home ...   0.984071
#
#                                     production_companies  ... release_date  \
# 56     [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...   1995-11-02
# 33785  [{'name': 'ABC Circle Films', 'id': 2166}, {'n...  ...   1974-07-13
#
#           revenue  runtime                                   spoken_languages  \
# 56     17519169.0    103.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 33785         0.0     73.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status vote_average  vote_count  \
# 56     Released          6.3        39.0
# 33785  Released          5.7         3.0
#
#                                                 keywords  \
# 56     [{'id': 2672, 'name': 'baltimore'}, {'id': 454...
# 33785  [{'id': 351, 'name': 'poison'}, {'id': 1156, '...
#
#                                                     cast  \
# 56     [{'cast_id': 10, 'character': 'Claudia Larson'...
# 33785  [{'cast_id': 10, 'character': 'Frederica Morga...
#
#                                                     crew
# 56     [{'credit_id': '52fe44dac3a36847f80ae00b', 'de...
# 33785  [{'credit_id': '52fe444c9251416c9100bc95', 'de...
#
# [2 rows x 21 columns]

# %%
print(data4.shape)
data5 = data4.drop_duplicates(subset=['original_title'], keep='first') # In most cases first movie among same name movies has the highest popularity hence we will keep them
print(data5.shape)
# Out:
# (46164, 21)
# (42955, 21)

# %%
data6 = data5
data6['release_date'] = data6['release_date'].apply(lambda x: x.split('-')[0])
data6 = data6.rename(index=str, columns={'release_date':'year'})

# %%
data6.production_companies[5]
# Out:
# "[{'name': 'Regency Enterprises', 'id': 508}, {'name': 'Forward Pass', 'id': 675}, {'name': 'Warner Bros.', 'id': 6194}]"

# %%
data6['cast'][2564]
# Out:
# '[{\'cast_id\': 1, \'character\': \'Mike\', \'credit_id\': \'52fe46ad9251416c7507feb3\', \'gender\': 2, \'id\': 4987, \'name\': \'Omar Epps\', \'order\': 0, \'profile_path\': \'/t4Qg5ANKK2idfOt4RzWzhiP7IEv.jpg\'}, {\'cast_id\': 2, \'character\': \'Slim\', \'credit_id\': \'52fe46ad9251416c7507feb7\', \'gender\': 2, \'id\': 55755, \'name\': \'Richard T. Jones\', \'order\': 1, \'profile_path\': \'/ccELAB9yHvG4OxG8dURdUXznwJ8.jpg\'}, {\'cast_id\': 4, \'character\': \'Roland\', \'credit_id\': \'52fe46ad9251416c7507febf\', \'gender\': 2, \'id\': 17637, \'name\': \'Taye Diggs\', \'order\': 2, \'profile_path\': \'/1g1demRAGhwdUpwi8PA0wgFe2IX.jpg\'}, {\'cast_id\': 3, \'character\': \'Young Alicia\', \'credit_id\': \'52fe46ad9251416c7507febb\', \'gender\': 1, \'id\': 74612, \'name\': \'Malinda Williams\', \'order\': 3, \'profile_path\': \'/hx4vstXwizQOSuFQ8awWO7fcR7Y.jpg\'}, {\'cast_id\': 5, \'character\': \'Young Mike\', \'credit_id\': \'52fe46ad9251416c7507fec3\', \'gender\': 2, \'id\': 75601, \'name\': \'Sean Nelson\', \'order\': 4, \'profile_path\': \'/8ylzaMgIfGxbaDrhe7uJmYBSFBB.jpg\'}, {\'cast_id\': 6, \'character\': \'Young Slim\', \'credit_id\': \'52fe46ad9251416c7507fec7\', \'gender\': 2, \'id\': 93535, \'name\': \'Duane Finley\', \'order\': 5, \'profile_path\': None}, {\'cast_id\': 7, \'character\': \'Young Roland\', \'credit_id\': \'52fe46ad9251416c7507fecb\', \'gender\': 2, \'id\': 63561, \'name\': \'Trent Cameron\', \'order\': 6, \'profile_path\': None}, {\'cast_id\': 8, \'character\': \'Stacey\', \'credit_id\': \'52fe46ad9251416c7507fecf\', \'gender\': 2, \'id\': 93538, \'name\': "De\'Aundre Bonds", \'order\': 7, \'profile_path\': \'/3zCQRZ6bkUNA9JKW6CDpjz1whrK.jpg\'}, {\'cast_id\': 9, \'character\': \'Tanya\', \'credit_id\': \'52fe46ad9251416c7507fed3\', \'gender\': 1, \'id\': 59154, \'name\': \'Tamala Jones\', \'order\': 8, \'profile_path\': \'/gG0PHm94ArObvF8LqbuoaWP2ye5.jpg\'}, {\'cast_id\': 10, \'character\': \'Alicia\', \'credit_id\': \'52fe46ad9251416c7507fed7\', \'gender\': 1, \'id\': 5411, \'name\': \'Sanaa Lathan\', \'order\': 9, \'profile_path\': \'/pnLeXOKrKquzk0R9cp1lpDKoEZP.jpg\'}, {\'cast_id\': 13, \'character\': \'Lisa\', \'credit_id\': \'52fe46ad9251416c7507fee7\', \'gender\': 1, \'id\': 105880, \'name\': \'LisaRaye McCoy\', \'order\': 10, \'profile_path\': \'/cQex5h9GuQnHU7kLthyB0e8MpMI.jpg\'}]'

# %%
data6['crew'][0]
# Out:
# '[{\'credit_id\': \'52fe4284c3a36847f8024f49\', \'department\': \'Directing\', \'gender\': 2, \'id\': 7879, \'job\': \'Director\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f4f\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12891, \'job\': \'Screenplay\', \'name\': \'Joss Whedon\', \'profile_path\': \'/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f55\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7, \'job\': \'Screenplay\', \'name\': \'Andrew Stanton\', \'profile_path\': \'/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f5b\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12892, \'job\': \'Screenplay\', \'name\': \'Joel Cohen\', \'profile_path\': \'/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f61\', \'department\': \'Writing\', \'gender\': 0, \'id\': 12893, \'job\': \'Screenplay\', \'name\': \'Alec Sokolow\', \'profile_path\': \'/v79vlRYi94BZUQnkkyznbGUZLjT.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f67\', \'department\': \'Production\', \'gender\': 1, \'id\': 12894, \'job\': \'Producer\', \'name\': \'Bonnie Arnold\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f6d\', \'department\': \'Production\', \'gender\': 0, \'id\': 12895, \'job\': \'Executive Producer\', \'name\': \'Ed Catmull\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f73\', \'department\': \'Production\', \'gender\': 2, \'id\': 12896, \'job\': \'Producer\', \'name\': \'Ralph Guggenheim\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f79\', \'department\': \'Production\', \'gender\': 2, \'id\': 12897, \'job\': \'Executive Producer\', \'name\': \'Steve Jobs\', \'profile_path\': \'/mOMP3SwD5qWQSR0ldCIByd3guTV.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f8b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 8, \'job\': \'Editor\', \'name\': \'Lee Unkrich\', \'profile_path\': \'/bdTCCXjgOV3YyaNmLGYGOxFQMOc.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f91\', \'department\': \'Art\', \'gender\': 2, \'id\': 7883, \'job\': \'Art Direction\', \'name\': \'Ralph Eggleston\', \'profile_path\': \'/uUfcGKDsKO1aROMpXRs67Hn6RvR.jpg\'}, {\'credit_id\': \'598331bf925141421201044b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 1168870, \'job\': \'Editor\', \'name\': \'Robert Gordon\', \'profile_path\': None}, {\'credit_id\': \'5892168cc3a36809660095f9\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1552883, \'job\': \'Foley Editor\', \'name\': \'Mary Helen Leasman\', \'profile_path\': None}, {\'credit_id\': \'5531824d9251415289000945\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 1453514, \'job\': \'Animation\', \'name\': \'Kim Blanchette\', \'profile_path\': None}, {\'credit_id\': \'589215969251412dcb009bf6\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1414182, \'job\': \'ADR Editor\', \'name\': \'Marilyn McCoppen\', \'profile_path\': None}, {\'credit_id\': \'589217099251412dc500a018\', \'department\': \'Sound\', \'gender\': 2, \'id\': 7885, \'job\': \'Orchestrator\', \'name\': \'Randy Newman\', \'profile_path\': \'/w0JzfoiM25nrnxYOzosPHRq6mlE.jpg\'}, {\'credit_id\': \'5693e6b29251417b0e0000e3\', \'department\': \'Editing\', \'gender\': 0, \'id\': 1429549, \'job\': \'Color Timer\', \'name\': \'Dale E. Grahn\', \'profile_path\': None}, {\'credit_id\': \'572e2522c3a36869e6001a9c\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 7949, \'job\': \'CG Painter\', \'name\': \'Robin Cooper\', \'profile_path\': None}, {\'credit_id\': \'574f12309251415ca1000012\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7879, \'job\': \'Original Story\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'574f1240c3a3682e7300001c\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12890, \'job\': \'Original Story\', \'name\': \'Pete Doct ...

# %%
data6['keywords'][0]
# Out:
# "[{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]"

# %%
data5['genres'][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
import re # import Regular Expression

data7 = data6

data7['popularity'] = data7['popularity'].apply(lambda x: float(x))

data7['budget'] = data7['budget'].apply(lambda x: x if x != 0 else 'Not Available')

data7['belongs_to_collection'] = data7['belongs_to_collection'].apply(lambda x: x.split(': ')[2].split(',')[0][1:-1] if x != 'Not Available' else ' ')

pattern = ",\s'name':\s'([A-z\s]+)"
data7['genres'] = data7['genres'].apply(lambda x: ' '.join([w for w in re.findall(pattern, x)]) if len(re.findall(pattern, x)) != 0 else ' ')

pattern = "{'name':\s'([A-z\s]+)',\s'"
data7['production_companies'] = data7['production_companies'].apply(lambda x: ' '.join([w for w in re.findall(pattern, x)]))

data7['production_countries'] = data7['production_countries'].apply(lambda x: ' '.join([w for w in re.findall('[A-Z][A-Z]', x)]) if len(re.findall('[A-Z][A-Z]', x)) else ' ')

pattern = ",\s'name':\s'([A-z\s]+)"
data7['cast'] = data7['cast'].apply(lambda x: ' '.join([w for w in re.findall(pattern, x)[0:3]]))

pattern = ":\s\'Director\',\s\'name\':\s\'([A-z\s]+)"
data7['director'] = data7['crew'].apply(lambda x: re.findall(pattern, x)[0] if len(re.findall(pattern, x)) != 0 else ' ')
data7 = data7.drop(['crew', 'spoken_languages'], axis=1)

pattern = ",\s'name':\s'([A-z\s]+)"
data7['keywords'] = data7['keywords'].apply(lambda x: ' '.join([w for w in re.findall(pattern, x)]))

data7.head()
# Out:
#    adult           belongs_to_collection    budget                    genres  \
# 0  False            Toy Story Collection  30000000   Animation Comedy Family
# 1  False                                  65000000  Adventure Fantasy Family
# 2  False       Grumpy Old Men Collection         0            Romance Comedy
# 3  False                                  16000000      Comedy Drama Romance
# 4  False  Father of the Bride Collection         0                    Comedy
#
#       id original_language               original_title  \
# 0    862                en                    Toy Story
# 1   8844                en                      Jumanji
# 2  15602                en             Grumpier Old Men
# 3  31357                en            Waiting to Exhale
# 4  11862                en  Father of the Bride Part II
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#                                 production_companies production_countries  \
# 0                            Pixar Animation Studios                   US
# 1  TriStar Pictures Teitler Film Interscope Commu...                   US
# 2                                     Lancaster Gate                   US
# 3             Twentieth Century Fox Film Corporation                   US
# 4          Sandollar Productions Touchstone Pictures                   US
#
#    year      revenue runtime    status  vote_average  vote_count  \
# 0  1995  373554033.0    81.0  Released           7.7      5415.0
# 1  1995  262797249.0   104.0  Released           6.9      2413.0
# 2  1995          0.0   101.0  Released           6.5        92.0
# 3  1995   81452156.0   127.0  Released           6.1        34.0
# 4  1995   76578911.0   106.0  Released           5.7       173.0
#
#                                             keywords  \
# 0  jealousy toy boy friendship friends rivalry bo...
# 1  board game disappearance new home recluse gian...
# 2   fishing best friend duringcreditsstinger old men
# 3  based on novel interracial relationship single...
# 4  baby midlife crisis confidence aging daughter ...
#
#                                             cast         director
# 0                Tom Hanks Tim Allen Don Rickles    John Lasseter
# 1     Robin Williams Jonathan Hyde Kirsten Dunst     Joe Johnston
# 2                 Walter Matthau Jack Lemmon Ann    Howard Deutch
# 3  Whitney Houston Angela Bassett Loretta Devine  Forest Whitaker
# 4         Steve Martin Diane Keaton Martin Short    Charles Shyer

# %%
language_stats = data7['original_language'].value_counts(ascending=False)
language_stats
# Out:
# en    30136
# fr     2351
# it     1499
# ja     1326
# de     1038
#       ...
# ay        1
# fy        1
# rw        1
# qu        1
# si        1
# Name: original_language, Length: 89, dtype: int64

# %%
small_movie_collections_by_language = language_stats[language_stats<300]
data7.original_language = data7.original_language.apply(lambda x: 'other' if x in small_movie_collections_by_language else x)
data8 = data7[data7.original_language!='other']
len(data7.original_language.unique())
# Out:
# 14

# %%
major_languages = list(data8.original_language.unique())
print(major_languages)
# Out:
# ['en', 'fr', 'zh', 'it', 'de', 'cn', 'es', 'ru', 'sv', 'ja', 'ko', 'pt', 'hi']

# %%
pip install googletrans
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans) (2023.7.22)
# Collecting hstspreload (from httpx==0.13.3->googletrans)
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 12.9 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.2 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.6 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.8 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15717 sha256=690a2932747a5c8d37845d78e56b4102f2ea707eb699982e85985c39295385e9
#   Stored in directory: /root/.cache/pip/wheels/b3/81/ea/8b030407f8ebfc2f857814e086bb22ca2d4fea1a7be63652ab
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed chardet-3.0.4 googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
import googletrans

univ_lang = googletrans.LANGUAGES
print(univ_lang)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'latin', 'lv': 'latvian', 'lt': 'lithuanian', 'lb': 'luxembourgish', 'mk': 'macedonian', 'mg': 'malagasy', 'ms': 'malay', 'ml': 'malayalam', 'mt': 'maltese', 'mi': 'maori', 'mr': 'marathi', 'mn': 'mongolian', 'my': 'myanmar (burmese)', 'ne': 'nepali', 'no': 'norwegian', 'or': 'odia', 'ps': 'pashto', 'fa': 'persian', 'pl': 'polish', 'pt': 'portuguese', 'pa': 'punjabi', 'ro': 'romanian', 'ru': 'russian', 'sm': 'samoan', 'gd': 'scots gaelic', 'sr': 'serbian', 'st': 'sesotho', 'sn': 'shona', 'sd': 'sindhi', 'si': 'sinhala', 'sk': 'slovak', 'sl': 'slovenian', 'so': 'somali', 'es': 'spanish', 'su': 'sundanese', 'sw': 'swahili', 'sv': 'swedish', 'tg': 'tajik', 'ta': 'tamil', 'te': 'telugu', 'th': 'thai', 'tr': 'turkish', 'uk': 'ukrainian', 'ur': 'urdu', 'ug': 'uyghur', 'uz': 'uzbek', 'vi': 'vietnamese', 'cy': 'welsh', 'xh': 'xhosa', 'yi': 'yiddish', 'yo': 'yoruba', 'zu': 'zulu'}

# %%
data9 = data8
data9['original_language'] = data9['original_language'].apply(lambda x: 'zh-cn' if x =='zh' else x)
data9['original_language'] = data9['original_language'].apply(lambda x: 'zh-cn' if x =='cn' else x)

data9['original_language'] = data9['original_language'].apply(lambda x: univ_lang[x])

# %%
data9['original_language'].value_counts(dropna=True).sort_index().plot(kind='barh',figsize=(10,6), color='green')
plt.grid()
plt.show()

# %%
data9['New_genre'] = data9.genres.apply(lambda x: [(i+' ')*((3)-re.findall('[A-z]+', x).index(i)) for i in re.findall('[A-z]+', x)])
data9['New_genre'] = data9['New_genre'].apply(lambda x: ' '.join([w for w in x]))

# %%
# function to plot most frequent terms
import nltk # Natural language processing toolkit
from nltk import FreqDist # Frequency distribution

def freq_words(x, terms = 30):
    all_words = ' '.join([text for text in x])
    all_words = all_words.split()

    fdist = FreqDist(all_words)
    words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})

    # selecting top 30 most frequent words
    d = words_df.nlargest(columns="count", n = terms)
    plt.figure(figsize=(20,5))
    ax = sns.barplot(data=d, x= "word", y = "count")
    ax.set(ylabel = 'Count')
    ax.set(xlabel = 'Words')
    plt.title('Most Common Words', weight='bold', fontsize=12)
    plt.show()

# %%
freq_words(data9['genres'], 10)

# %%
# Using wordcloud to visually represent the text data
def wordcloud_draw(data1, color1 = 'black'):
    words1 = ' '.join(data1)
    cleaned_word1 = " ".join([word for word in words1.split(' ')
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    wordcloud1 = WordCloud(stopwords=STOPWORDS,
                      background_color=color1,
                      width=2500,
                      height=2000
                      ).generate(cleaned_word1)


    plt.figure(figsize=(10,10))
    plt.axis('off')
    plt.title('Genres', weight='bold', fontsize=20)
    plt.imshow(wordcloud1)
    plt.show()

# %%
wordcloud_draw(set(data9['genres'].values))

# %%
freq_words(data9['keywords'], 20)

# %%
data9[data9['original_language']=='english'].sort_values('popularity', ascending=False).head(50)
# Out:
#        adult                   belongs_to_collection     budget  \
# 30910  False                Despicable Me Collection   74000000
# 44809  False                                           34000000
# 24657  False                                          165000000
# 26779  False                     Deadpool Collection   58000000
# 26781  False      Guardians of the Galaxy Collection  200000000
# 14723  False                       Avatar Collection  237000000
# 24553  False                    John Wick Collection   20000000
# 23870  False                                           61000000
# 25074  False             The Hunger Games Collection  125000000
# 45439  False  Planet of the Apes (Reboot) Collection  152000000
# 26782  False              Captain America Collection  250000000
# 292    False                                            8000000
# 26775  False     Pirates of the Caribbean Collection  230000000
# 12589  False              The Dark Knight Collection  185000000
# 536    False                 Blade Runner Collection   28000000
# 44451  False                                           38000000
# 45436  False                                            6000000
# 24316  False              The Maze Runner Collection   34000000
# 23887  False  Planet of the Apes (Reboot) Collection  170000000
# 44067  False                   Prometheus Collection   97000000
# 43475  False                                          110000000
# 44466  False                   Undisputed Collection          0
# 23868  False                                            3300000
# 2870   False                                           63000000
# 45789  False                                                  0
# 46365  False                                                  0
# 23948  False      Guardians of the Galaxy Collection  170000000
# 40862  False                                            5500000
# 314    False                                           25000000
# 43334  False                    John Wick Collection   40000000
# 44420  False     The Fast and the Furious Collection  250000000
# 351    False                                           55000000
# 6459   False     Pirates of the Caribbean Collection  140000000
# 46194  False                                           15000000
# 40499  False                                          180000000
# 43380  False                                          175000000
# 30753  False                                          175000000
# 256    False                    Star Wars Collection   11000000
# 30900  False                          Ted Collection   68000000
# 522    False                                           22000000
# 17778  False  Planet of the Apes (Reboot) Collection   93000000
# 40499  3.567431e+08    109.0  Released          5.5      2488.0
# 43380  1.461751e+08    126.0  Released          6.5      1506.0
# 30753  7.456001e+08    123.0  Released          5.9      7717.0
# 256    7.753980e+08    121.0  Released          8.1      6778.0
# 30900  2.170226e+08    115.0  Released          6.2      2524.0
# 522    3.213656e+08    195.0  Released          8.3      4436.0
# 17778  4.828602e+08    105.0  Released          7.0      4452.0
# 25407  3.112569e+08    132.0  Released          6.5      3148.0
# 841    2.450664e+08    175.0  Released          8.5      6024.0
# 30611  8.093423e+08    133.0  Released          7.2      5612.0
# 46330  1.847702e+08    111.0  Released          7.4       181.0
# 40019  3.349013e+08    129.0  Released          6.7      3362.0
# 46005  6.049421e+08    149.0  Released          6.2      1440.0
# 43351  1.002557e+07     98.0  Released          6.8       651.0
# 4807   9.764756e+08    152.0  Released          7.5      7188.0
# 46367  0.000000e+00    122.0  Released          7.1       393.0
#
#                                                 keywords  \
# 30910  assistant aftercreditsstinger duringcreditssti...
# 44809  robbery atlanta music crime boss romance tinni...
# 24657  brother brother relationship hero talent reven...
# 26779  anti hero mercenary marvel comic superhero bas...
# 26781  sequel superhero based on comic misfit space o...
# 14723  culture clash future space war space colony so...
# 24553  hitman russian mafia revenge murder gangster d...
# 23870  based on novel marriage crisis disappearance c...
# 25074  resistance post dystopia war sequel female pro...
# 45439           based on novel sequel talking animal ape
# 26782  civil war war marvel comic sequel superhero ba...
# 292    transporter brothel drug dealer boxer massage ...
# 26775  sea ship sequel artifact treasure map pirate p...
# 12589  dc comics crime fighter secret identity scarec...
# 536    artificial intelligence bounty hunter dystopia...
# 44451            underwear school principal grade school
# 45436  amputation kidnapping post dystopia exile drug...
# 24316  based on novel maze post dystopia escape memor...
# 23887  leader colony post dystopia forest sequel wood...
# 44067  android space travel alien life infection egg ...
# 43475  philosophy cyborg hacker strong woman investig...
# 44466        prison wife sport fighting accidental death
# 23868  jazz obsession conservatory music teacher new ...
# 2870   support group dual identity nihilism rage and ...
# 45789  chase false identity overpopulation investigat...
# 46365                             magic wish fulfillment
# 23948  marvel comic spaceship space outer space orpha...
# 40862  diving sister sister relationship shark attack...
# 314    prison corruption police brutality prison cell...
# 43334              italy gun roof party sequel handshake
# 44420  submarine sequel betrayal fast cars rescue mis...
# 351    vietnam veteran hippie mentally disabled runni...
# 6459   exotic island blacksmith east india trading co...
# 46194
# 40499     africa feral child tarzan jungle animal attack
# 43380                     sword king arthur period drama
# 30753  dc comics shared universe anti hero secret mis...
# 256    android galaxy hermit death star lightsaber je...
# 30900  sperm bank sequel buddy courthouse teddy bear ...
# 522    factory concentration camp hero holocaust worl...
# 17778  intelligence zoo cage dystopia golden gate bri...
# 25407  based on novel resistance maze post dystopia i...
# 841    italy love at first sight loss of father patri...
# 30611  robbery magic teleportation suitcase new york ...
# 46330  rape mountain gun investigation murder native ...
# 40019  london england china magic secret society vigi...
# 46005                                knight transformers
# 43351  based on novel time loop teenager mumblecore t...
# 4807   witch christmas party magic cutting the cord h...
# 46367
#
#                                                     cast  \
# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def recommendations(title, df= data9):

    lang = df[(df['original_title']==title)]['original_language'].iloc[0]

    if lang != 'english':
        data = df[(df['original_language']==lang)]
    else:
        data = df[(df['original_language']==lang)]
        data = data[(data['popularity'] > 1.3)]
        data = data[(data['vote_count'] >= 50)]

    def combined_feature(row):
        return row['belongs_to_collection']+' '+row['New_genre']+' '+row['overview']+' '+row['cast']+' '+row['director']+' '+row['keywords']+' '+row['original_title']

    data['combined_features'] = data.apply(combined_feature, axis=1)
    data['combined_features'] = data['combined_features'].apply(lambda x: ' '.join([w.lower() for w in x.split(' ')]))

    import nltk
    from nltk.corpus import stopwords
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity

    stopset = set(stopwords.words('english'))
    vectorizer = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, strip_accents='ascii', stop_words='english')
    count_matrix = vectorizer.fit_transform(data.combined_features)
    cosine_sim = cosine_similarity(count_matrix)

    def weighted_rating(x):
        v = x['vote_count']
        R = x['vote_average']
        return (v/(v+m) * R) + (m/(m+v) * C)

    data.reset_index(inplace=True)
    indices = pd.Series(data.index, index = data['original_title']).drop_duplicates()


    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores.sort(key=lambda x: x[1], reverse= True)
    sim_scores = sim_scores[1:50]
    movie_indices = [i[0] for i in sim_scores]

    movies = data.iloc[movie_indices][['original_title', 'vote_count', 'vote_average', 'year', 'genres', 'original_language']]
    vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = movies[movies['vote_average'].notnull()]['vote_average']
    C = vote_averages.mean()
    m = vote_counts.quantile(0.60)

    qualified = movies
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average']
    qualified['wr'] = qualified.apply(weighted_rating, axis=1)

    del cosine_sim

    return qualified.iloc[0:10,:].sort_values('wr', ascending=False)

recommendations("Iron Man")
# Out:
#                                          original_title  vote_count  \
# 6035                            Avengers: Age of Ultron        6908
# 6040                         Captain America: Civil War        7462
# 6037                                            Ant-Man        6029
# 5333                                         Iron Man 3        8951
# 4509                                         Iron Man 2        6969
# 6832                 Marvel One-Shot: All Hail the King         102
# 6884  Marvel One-Shot: A Funny Thing Happened on the...          72
# 6123                           Marvel One-Shot: Item 47         114
# 6833                    Marvel One-Shot: The Consultant         108
# 4005                                The Incredible Hulk        3086
#
#       vote_average  year                                    genres  \
# 6035           7.3  2015          Action Adventure Science Fiction
# 6040           7.1  2016          Adventure Action Science Fiction
# 6037           7.0  2015          Science Fiction Action Adventure
# 5333           6.8  2013          Action Adventure Science Fiction
# 4509           6.6  2010          Adventure Action Science Fiction
# 6832           7.0  2014      Comedy Action Drama Thriller Fantasy
# 6884           7.0  2011                   Science Fiction Fantasy
# 6123           6.6  2012            Science Fiction Action Fantasy
# 6833           6.6  2011  Adventure Fantasy Science Fiction Action
# 4005           6.1  2008          Science Fiction Action Adventure
#
#      original_language        wr
# 6035           english  6.967905
# 6040           english  6.852605
# 6037           english  6.756043
# 5333           english  6.672117
# 4509           english  6.520365
# 6832           english  6.393471
# 6884           english  6.388874
# 6123           english  6.383891
# 6833           english  6.383566
# 4005           english  6.254699
